# %%
item = int(input("Enter item to search: "))
print("item is",item)
# Out:
# item is 45

# %%
item = int(input("Enter item to search: "))
print("item is",item)

# %%
lst = [12, 45, 33, 21, 88]
if item in lst:
    print(f"Item found at position {lst.index(item)}")
else:
    print("Item not found.")
# Out:
# Item found at position 2
