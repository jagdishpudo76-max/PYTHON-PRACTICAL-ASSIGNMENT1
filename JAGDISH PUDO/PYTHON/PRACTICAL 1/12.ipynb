# %%
students = ["jagdish", "Ram", "Lokesh", "Mukesh", "Kunal", "Rahul"]

print("Student List:", students)
# Out:
# Student List: ['jagdish', 'Ram', 'Lokesh', 'Mukesh', 'Kunal', 'Rahul']

# %%
import random

students = ["jagdish", "Ram", "Lokesh", "Mukesh", "Kunal", "Rahul"]

# Select CR randomly
cr = random.choice(students)
print("Selected CR:", cr)

# Shuffle the list
random.shuffle(students)
print("Shuffled Student List:", students)
# Out:
# Selected CR: Rahul
# Shuffled Student List: ['Lokesh', 'Ram', 'jagdish', 'Kunal', 'Rahul', 'Mukesh']
