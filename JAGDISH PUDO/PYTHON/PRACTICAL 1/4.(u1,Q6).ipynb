# %%
import statistics as st

nums = list(map(int, input("Enter numbers separated by space: ").split()))
print("nums is ",nums)
# Out:
# nums is  [12, 45, 33, 21, 88]

# %%
print("Mean  =", st.mean(nums))
print("Median =", st.median(nums))
print("Mode  =", st.mode(nums))
# Out:
# Mean  = 39.8
# Median = 33
# Mode  = 12
