# %%
import math

# %%
num = int(input("enter a number: "))
print(math.sqrt(num))
print(math.factorial(num))
print(math.pow(num, 3))
# Out:
# 2.23606797749979
# 120
# 125.0

# %%
import math
num = float(int(input("enter a number")))
area =2*math.pi*num
print("circumference of circle =",area)
# Out:
# circumference of circle = 31.41592653589793

# %%
import random
student =["aman","liladar","kunal","jagdish","mukesh"]
random.shuffle(student)
print(student)
a = random.choice(student)
print("cr is",a)
# Out:
# ['aman', 'liladar', 'kunal', 'jagdish', 'mukesh']
# cr is aman

# %%
import math
a =int(input("enter a number:"))
b =int(input("enter a number:"))
print(math.perm(a, b))
print(math.comb(a,b))
# Out:
# 2520
# 21
