# %%
number = int(input("Enter the number :"))
# binary = bin(number)[2:]
# octal = oct(number)[2:]
# hexa = hex(number)[2:]
# print("Conver binary",binary," ",octal," ",hexa)
def binary(number):
    if number<1024:
        binary = bin(number)[2:]
        print("Binary",binary)
    else:
        print("Error")
# Out:
# Binary 1111111111

# %%
binary(number)
