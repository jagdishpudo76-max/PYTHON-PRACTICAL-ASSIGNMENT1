# %%
import keyboard
import random

print ("choose an option from thisthree:\nsnake \nwater\ngun\n")

"""opt = input ("enter option:")
option-opt.lower()"""

option_list =["snake","water","gun"]

def opt_input(): 
    opt=input("enter option:")
    option=opt.lower()
    return option

def check_input(x):
    if x in option_list:
        print(F"entered option :{x}")
        return True
    else:
        print(F"entered option : {x}")
    
        print(f"invalid input, please enter valid input")
        return False
    
flage=False
while flage==False:
    if(keyboard.is_pressed('esc')):
        break
    str=opt_input()
    flage=check_input(str)
# Out:
# choose an option from thisthree:
# snake
# water
# gun
#
# entered option : sneke
# invalid input, please enter valid input
# entered option :
# invalid input, please enter valid input
