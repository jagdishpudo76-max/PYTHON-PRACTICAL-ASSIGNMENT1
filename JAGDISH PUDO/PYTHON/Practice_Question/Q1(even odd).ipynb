# %%
num =int(input("enter a number"))
if num%2 == 0:
    print("even numbre")
else:
    print("odd number")
# Out:
# even numbre

# %%
import math
num = float(input("enter a number"))
area =2*math.pi*num
print(area)
# Out:
# 31.41592653589793

# %%
num= int(input("enter a number"))
for i in range(1,11):
 #a= num*i
 print(num*i)
# Out:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
str = "abecdipoture"
v=str.count("e")
print(v)
# Out:
# 2

# %%
text = input("Enter a string: ")
vowels = "aeiouAEIOU"
count = 0

for i in text:
    if i in vowels:
        count += 1

print("Number of vowels:", count)
# Out:
# Number of vowels: 5

# %%
str = input('enter a string')
rev =""
for i in str:
    rev = i+rev
print(rev)
# Out:
# hsidgaj

# %%
string = input("Enter a string: ")
rev = ""

for char in string:
    rev = char + rev

print("Reversed string:", rev)
# Out:
# Reversed string: hsidgaj

# %%
str =input("enter a string")
copy_str1=str.copy()
copy_str1.reverse()
if(copy_str1==str1):
    print("palindrom")
else:
    print("not palindrom")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 2
#       1 str =input("enter a string")
# ----> 2 copy_str1=str.copy()
#       3 copy_str1.reverse()
#       4 if(copy_str1==str1):
#
# AttributeError: 'str' object has no attribute 'copy'
