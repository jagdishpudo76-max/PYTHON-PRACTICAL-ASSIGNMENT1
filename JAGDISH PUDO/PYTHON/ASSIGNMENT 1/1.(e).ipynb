# %%
rows = 3
cols = 5
for i in range(rows):
    for j in range(cols):

        if (i == 0 and (j == 0 or j == 4)) or (i == 1 and j == 2) or (i == 2 and (j == 0 or j == 4)):
            print("*", end="")
        else:
            print(" ", end="")
    print()
# Out:
# *   *
#   *
# *   *
