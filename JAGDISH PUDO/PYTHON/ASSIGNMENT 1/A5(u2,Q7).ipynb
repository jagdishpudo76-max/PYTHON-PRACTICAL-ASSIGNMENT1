# %%
employees = [
    {"name": 'John', "salary": 30000},
    {"name": 'Mary', "salary": 52000},
    {"name": 'Alex', "salary": 60000}
]

sorted_list = sorted(employees, key=lambda x: x["salary"])
print("Sorted by Salary:", sorted_list)
# Out:
# Sorted by Salary: [{'name': 'John', 'salary': 30000}, {'name': 'Mary', 'salary': 52000}, {'name': 'Alex', 'salary': 60000}]
