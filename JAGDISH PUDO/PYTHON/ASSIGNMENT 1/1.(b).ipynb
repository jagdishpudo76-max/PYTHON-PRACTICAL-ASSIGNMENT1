# %%
rows = 4
for i in range(1, rows + 1):
    print(" " * (rows - i), end="")
    print("*" *(2* i-1))
# Out:
#    *
#   ***
#  *****
# *******

# %%
for i in range(1,6):
    for j in range(0,j):
        print("*",end="")
    print("")
