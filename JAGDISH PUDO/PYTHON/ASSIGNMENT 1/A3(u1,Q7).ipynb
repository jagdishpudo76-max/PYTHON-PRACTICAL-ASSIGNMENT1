# %%
num = int(input("Enter number: "))
print("number is",num)
# Out:
# number is 5

# %%
def fact(n):
    if n == 0 or n == 1:
        return 1
    return n * fact(n - 1)
print("Factorial:", fact(num))
# Out:
# Factorial: 120
